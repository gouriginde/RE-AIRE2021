# %%
import matplotlib.pyplot as plt

# %%
# BERT
# Redmine
# line 1 points
xB_Redmine=[6.41,12.8,19.23,25.64,32.05,38.46,44.87,51.28,57.69,64.10,70.51,76.92,83.33,89.74,96.15,100]
precisionB_Redmine=[0.61,0.8,0.84,0.86,0.85,0.86,0.86,0.88,0.88,0.89,0.89,0.89,0.89,0.9,0.91,0.92]
recallB_Redmine=[0.76,0.84,0.85,0.86,0.88,0.87,0.89,0.9,0.9,0.91,0.92,0.93,0.92,0.94,0.94,0.95]


#Random Forest
# Redmine
# line 2 points
xR_Redmine=[250,500,750,1000,1250,1500,1750,2000,2250,2500,2750,3000,3250,3500,3750,3900]
precisionR_Redmine=[0.59,0.64,0.64,0.67,0.69,0.71,0.72,0.73,0.77,0.78,0.78,0.8,0.81,0.81,0.84,0.84]
recallR_Redmine=[0.62,0.62,0.68,0.65,0.7,0.7,0.73,0.72,0.73,0.77,0.77,0.79,0.81,0.84,0.86,0.86]

# %%
# Redmine
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(14,6))
fig.subplots_adjust(hspace=0.25)
fig.subplots_adjust(wspace=0.28)
ax[0].plot(xB_Redmine,precisionB_Redmine,color='r',label='BERT_Precision')
ax[0].plot(xB_Redmine,precisionR_Redmine,color='b',linestyle='dashed',label='RF_Precision')
ax[0].set_xlabel('Relative size of training set(%)',fontsize=15)
ax[0].set_ylabel('Precision(Relates class)',fontsize=15)
ax[0].legend()
ax[0].grid()
# ax[0].set_title('Redmine', fontsize=18)

ax[1].plot(xB_Redmine,recallB_Redmine,color='r',label='BERT_Recall')
ax[1].plot(xB_Redmine,recallR_Redmine,color='b',linestyle='dashed',label='RF_Recall')
ax[1].set_xlabel('Relative size of training set(%)',fontsize=15)
ax[1].set_ylabel('Recall(Relates class)',fontsize=15)
ax[1].legend()
ax[1].grid()
# ax[1].set_title('Redmine',fontsize=18)
fig.savefig('BERT_RF_Parameter.jpeg')
